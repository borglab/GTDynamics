# %% [markdown]
# # CM-OPT Benchmark Dashboard
#
# Run and compare `example_constraint_manifold_arm`, `example_constraint_manifold_connected_poses`, and `example_constraint_manifold_cable_robot` from Python.
#
# This notebook:
# - runs each benchmark with `subprocess`
# - captures logs per benchmark
# - reads a CSV emitted by C++ benchmark helpers
# - prints tables via `tabulate`
# - renders Plotly comparisons

# %%
from __future__ import annotations

import csv
import datetime as dt
import os
import re
import subprocess
import time
from pathlib import Path

from tabulate import tabulate
import plotly.graph_objects as go

# Update if needed
REPO_ROOT = Path('/Users/dellaert/git/GTDynamics')
BUILD_DIR = REPO_ROOT / 'build'
LOG_DIR = BUILD_DIR / 'benchmark_logs_cmopt_notebook'
CSV_PATH = LOG_DIR / 'benchmark_results.csv'
STATUS_PATH = LOG_DIR / 'run_status.csv'

DEFAULT_EXPECTED_METHODS = [
    'Soft Constraint',
    'Penalty Method',
    'Augmented Lagrangian',
    'Constraint Manifold (F)',
    'Constraint Manifold (I)',
]

TARGETS = {
    'arm': {
        'build_target': 'example_constraint_manifold_arm',
        'executable': 'examples/example_constraint_manifold/example_constraint_manifold_arm',
        'args': ['--skip-cm-f'],
        'expected_methods': [
            'Soft Constraint',
            'Penalty Method',
            'Augmented Lagrangian',
            'Constraint Manifold (I)',
        ],
    },
    'arm_cm_f_only': {
        'build_target': 'example_constraint_manifold_arm',
        'executable': 'examples/example_constraint_manifold/example_constraint_manifold_arm',
        'benchmark_id': 'arm',
        'run_timeout_s': 180,
        'args': ['--cm-f-only'],
        'expected_methods': [
            'Constraint Manifold (F)',
        ],
    },
    'connected_poses': {
        'build_target': 'example_constraint_manifold_connected_poses',
        'executable': 'examples/example_constraint_manifold/example_constraint_manifold_connected_poses',
    },
    'cable_robot': {
        'build_target': 'example_constraint_manifold_cable_robot',
        'executable': 'examples/example_constraint_manifold/example_constraint_manifold_cable_robot',
    },
}

JOBS = 2
RUN_TIMEOUT_S = 240
PRINT_SUBPROCESS_OUTPUT = True
BENCHMARK_VERBOSE = False
RETRACTOR_VERBOSE = False

LOG_DIR.mkdir(parents=True, exist_ok=True)
print(f'REPO_ROOT: {REPO_ROOT}')
print(f'BUILD_DIR: {BUILD_DIR}')
print(f'LOG_DIR: {LOG_DIR}')
# Out:
# REPO_ROOT: /Users/dellaert/git/GTDynamics
# BUILD_DIR: /Users/dellaert/git/GTDynamics/build
# LOG_DIR: /Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook

# %%
def normalize_method(method: str) -> str:
    """Normalize method labels from C++ (including LaTeX wrappers)."""
    method = method.strip()
    m = re.fullmatch(r"\\textbf\{(.+)\}", method)
    return m.group(1) if m else method


def read_results_csv(path: Path):
    if not path.exists():
        return []

    rows = []
    with path.open('r', newline='') as f:
        reader = csv.DictReader(f)
        for row in reader:
            parsed = {
                'benchmark': row['benchmark'],
                'method_raw': row['method'],
                'method': normalize_method(row['method']),
                'f_dim': int(row['f_dim']),
                'v_dim': int(row['v_dim']),
                'time_s': float(row['time_s']),
                'iters': int(row['iters']),
                'constraint_l2': float(row['constraint_l2']),
                'cost': float(row['cost']),
            }
            rows.append(parsed)
    return rows


def write_status_csv(status_rows):
    with STATUS_PATH.open('w', newline='') as f:
        fieldnames = ['benchmark', 'benchmark_id', 'target', 'return_code', 'elapsed_s', 'timestamp_utc', 'log_path']
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(status_rows)


def run_one_target(benchmark: str, target_cfg: dict, jobs: int = 2):
    benchmark_id = target_cfg.get('benchmark_id', benchmark)
    run_timeout_s = target_cfg.get('run_timeout_s', RUN_TIMEOUT_S)
    build_target = target_cfg['build_target']
    executable = target_cfg['executable']
    extra_args = target_cfg.get('args', [])

    log_path = LOG_DIR / f'{benchmark}.log'
    env = os.environ.copy()
    env['GTDYN_BENCHMARK_CSV'] = str(CSV_PATH)
    env['GTDYN_BENCHMARK_ID'] = benchmark_id

    build_cmd = ['make', f'-j{jobs}', build_target]
    run_cmd = [str(BUILD_DIR / executable)]
    if BENCHMARK_VERBOSE:
        run_cmd.append('--verbose-benchmark')
    if RETRACTOR_VERBOSE:
        run_cmd.append('--verbose-retractor')
    run_cmd.extend(extra_args)
    build_cmd_str = ' '.join(build_cmd)
    run_cmd_str = ' '.join(run_cmd)
    print(f'Building: {build_cmd_str} (benchmark={benchmark})')

    start = time.perf_counter()
    timed_out = False
    with log_path.open('w') as log_file:
        build_log_pos = log_file.tell()
        build_result = subprocess.run(
            build_cmd,
            cwd=BUILD_DIR,
            env=env,
            text=True,
            stdout=log_file,
            stderr=subprocess.STDOUT,
        )
        if PRINT_SUBPROCESS_OUTPUT:
            log_file.flush()
            with log_path.open('r') as rf:
                rf.seek(build_log_pos)
                for line in rf:
                    if 'Built target' in line or 'error' in line.lower():
                        print(f'[{benchmark}] {line}', end='')

        if build_result.returncode != 0:
            elapsed = time.perf_counter() - start
            print(f'  -> build failed, return_code={build_result.returncode}, elapsed={elapsed:.2f}s, log={log_path}')
            return {
                'benchmark': benchmark,
                'benchmark_id': benchmark_id,
                'target': f"{build_target} -> {executable}",
                'return_code': build_result.returncode,
                'elapsed_s': elapsed,
                'timestamp_utc': dt.datetime.now(dt.UTC).isoformat(timespec='seconds').replace('+00:00', 'Z'),
                'log_path': str(log_path),
            }

        print(f'Running: {run_cmd_str} (benchmark={benchmark})')
        try:
            run_log_pos = log_file.tell()
            run_result = subprocess.run(
                run_cmd,
                cwd=BUILD_DIR,
                env=env,
                text=True,
                stdout=log_file,
                stderr=subprocess.STDOUT,
                timeout=run_timeout_s,
            )
            if PRINT_SUBPROCESS_OUTPUT:
                log_file.flush()
                with log_path.open('r') as rf:
                    rf.seek(run_log_pos)
                    for line in rf:
                        stripped = line.strip()
                        if (
                            stripped.startswith('[BENCH]')
                            or stripped.startswith('& ')
                            or stripped.startswith('soft constraints:')
                            or stripped.startswith('penalty method:')
                            or stripped.startswith('augmented lagrangian:')
                            or stripped.startswith('constraint manifold basis variables')
                        ):
                            print(f'[{benchmark}] {line}', end='')
            return_code = run_result.returncode
        except subprocess.TimeoutExpired:
            timed_out = True
            log_file.write('\n[TIMEOUT]\n')
            if PRINT_SUBPROCESS_OUTPUT:
                print(f'[TIMEOUT] process exceeded timeout={run_timeout_s}s')
            return_code = 124

    elapsed = time.perf_counter() - start
    timeout_suffix = ' (timeout)' if timed_out else ''
    print(f'  -> return_code={return_code}, elapsed={elapsed:.2f}s{timeout_suffix}, log={log_path}')

    return {
        'benchmark': benchmark,
        'benchmark_id': benchmark_id,
        'target': f"{build_target} -> {executable}",
        'return_code': return_code,
        'elapsed_s': elapsed,
        'timestamp_utc': dt.datetime.now(dt.UTC).isoformat(timespec='seconds').replace('+00:00', 'Z'),
        'log_path': str(log_path),
    }


def run_all_targets(clear_previous: bool = True, jobs: int = 2):
    LOG_DIR.mkdir(parents=True, exist_ok=True)
    if clear_previous:
        if CSV_PATH.exists():
            CSV_PATH.unlink()
        for p in LOG_DIR.glob('*.log'):
            p.unlink()

    status_rows = []
    for benchmark, target_cfg in TARGETS.items():
        status_rows.append(run_one_target(benchmark, target_cfg, jobs=jobs))

    write_status_csv(status_rows)
    return status_rows

# %%
# Run all benchmarks
run_status = run_all_targets(clear_previous=True, jobs=JOBS)

print()
print(tabulate(
    run_status,
    headers='keys',
    tablefmt='github',
    floatfmt='.3f',
))

print(f'\nstatus CSV: {STATUS_PATH}')
print(f'results CSV: {CSV_PATH}')
# Out:
# Building: make -j2 example_constraint_manifold_arm (benchmark=arm)
# [arm] [ 95%] Built target gtdynamics
# [arm] [100%] Built target example_constraint_manifold_arm
# Running: /Users/dellaert/git/GTDynamics/build/examples/example_constraint_manifold/example_constraint_manifold_arm --skip-cm-f (benchmark=arm)
# [arm] soft constraints:
# [arm] [BENCH] Soft Constraint: f_dim=688, v_dim=605, time_s=3.42, iters=205, constraint_l2=8.571e-03, cost=0.430867
# [arm] penalty method:
# [arm] [BENCH] Penalty Method: f_dim=688, v_dim=605, time_s=23.6674, iters=0, constraint_l2=2.670e-05, cost=0.234963
# [arm] augmented lagrangian:
# [arm] [BENCH] Augmented Lagrangian: f_dim=688, v_dim=605, time_s=17.477, iters=0, constraint_l2=1.063e-04, cost=0.233363
# [arm] constraint manifold basis variables (feasible): skipped (--skip-cm-f)
# [arm] constraint manifold basis variables (infeasible):
# [arm] [BENCH] CM(I) mode: using fast outer-LM settings (SEQUENTIAL_CHOLESKY, maxIterations=20, relativeErrorTol=1e-3, lambdaUpperBound=1e2).
# [arm] [BENCH] \textbf{Constraint Manifold (I)}: f_dim=146, v_dim=70, time_s=0.071, iters=0, constraint_l2=3.182e-03, cost=594.715
# [arm] & Soft Constraint & $688 \times 605$ & 3.42 & 205 & 8.57e-03 & 0.43\\
# [arm] & Penalty Method & $688 \times 605$ & 23.67 & 0 & 2.67e-05 & 0.23\\
# [arm] & Augmented Lagrangian & $688 \times 605$ & 17.48 & 0 & 1.06e-04 & 0.23\\
# [arm] & \textbf{Constraint Manifold (I)} & $146 \times 70$ & 0.071 & 0 & 3.18e-03 & 594.71\\
#   -> return_code=0, elapsed=81.82s, log=/Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/arm.log
# Building: make -j2 example_constraint_manifold_arm (benchmark=arm_cm_f_only)
# [arm_cm_f_only] [ 95%] Built target gtdynamics
# [arm_cm_f_only] [100%] Built target example_constraint_manifold_arm
# Running: /Users/dellaert/git/GTDynamics/build/examples/example_constraint_manifold/example_constraint_manifold_arm --cm-f-only (benchmark=arm_cm_f_only)
# [arm_cm_f_only] [BENCH] CM(F)-only mode enabled.
# [arm_cm_f_only] [BENCH] F-only mode: using bounded outer-LM settings (SEQUENTIAL_CHOLESKY, maxIterations=30, relativeErrorTol=1e-3, lambdaUpperBound=1e2).
# [arm_cm_f_only] [BENCH] F-only mode: skipping soft, penalty, augmented lagrangian, and CM(I).
# [arm_cm_f_only] constraint manifold basis variables (feasible):
# [arm_cm_f_only] [BENCH] \textbf{Constraint Manifold (F)}: f_dim=146, v_dim=70, time_s=0.072, iters=0, constraint_l2=3.182e-03, cost=594.715
# [arm_cm_f_only] constraint manifold basis variables (infeasible): skipped (F-only mode)
# [arm_cm_f_only] & \textbf{Constraint Manifold (F)} & $146 \times 70$ & 0.072 & 0 & 3.18e-03 & 594.71\\
#   -> return_code=0, elapsed=1.47s, log=/Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/arm_cm_f_only.log
# Building: make -j2 example_constraint_manifold_connected_poses (benchmark=connected_poses)
# [connected_poses] [ 95%] Built target gtdynamics
# [connected_poses] [100%] Built target example_constraint_manifold_connected_poses
# Running: /Users/dellaert/git/GTDynamics/build/examples/example_constraint_manifold/example_constraint_manifold_connected_poses (benchmark=connected_poses)
# [connected_poses] soft constraints:
# [connected_poses] [BENCH] Soft Constraint: f_dim=909, v_dim=606, time_s=0.627, iters=28, constraint_l2=7.525e+01, cost=13.5086
# [connected_poses] penalty method:
# [connected_poses] [BENCH] Penalty Method: f_dim=909, v_dim=606, time_s=3.09567, iters=0, constraint_l2=7.493e+01, cost=5.27731
# [connected_poses] augmented lagrangian:
# [connected_poses] [BENCH] Augmented Lagrangian: f_dim=909, v_dim=606, time_s=2.193, iters=0, constraint_l2=7.493e+01, cost=5.45672
# [connected_poses] constraint manifold basis variables (feasible):
# [connected_poses] [BENCH] \textbf{Constraint Manifold (F)}: f_dim=606, v_dim=303, time_s=1.578, iters=0, constraint_l2=6.384e+01, cost=9959.82
# [connected_poses] constraint manifold basis variables (infeasible):
# [connected_poses] [BENCH] \textbf{Constraint Manifold (I)}: f_dim=606, v_dim=303, time_s=1.324, iters=0, constraint_l2=7.255e+01, cost=5297.17
# [connected_poses] & Soft Constraint & $909 \times 606$ & 0.627 & 28 & 7.52e+01 & 13.51\\
# [connected_poses] & Penalty Method & $909 \times 606$ & 3.096 & 0 & 7.49e+01 & 5.28\\
# [connected_poses] & Augmented Lagrangian & $909 \times 606$ & 2.193 & 0 & 7.49e+01 & 5.46\\
# [connected_poses] & \textbf{Constraint Manifold (F)} & $606 \times 303$ & 1.578 & 0 & 6.38e+01 & 9959.82\\
# [connected_poses] & \textbf{Constraint Manifold (I)} & $606 \times 303$ & 1.324 & 0 & 7.26e+01 & 5297.17\\
#   -> return_code=0, elapsed=13.69s, log=/Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/connected_poses.log
# Building: make -j2 example_constraint_manifold_cable_robot (benchmark=cable_robot)
# [cable_robot] [ 95%] Built target gtdynamics
# [cable_robot] [100%] Built target example_constraint_manifold_cable_robot
# Running: /Users/dellaert/git/GTDynamics/build/examples/example_constraint_manifold/example_constraint_manifold_cable_robot (benchmark=cable_robot)
# [cable_robot] soft constraints:
# [cable_robot] [BENCH] Soft Constraint: f_dim=140, v_dim=110, time_s=1.213, iters=205, constraint_l2=6.052e-03, cost=0.344925
# [cable_robot] penalty method:
# [cable_robot] [BENCH] Penalty Method: f_dim=140, v_dim=110, time_s=5.9679, iters=0, constraint_l2=4.188e-05, cost=0.239275
# [cable_robot] augmented lagrangian:
# [cable_robot] [BENCH] Augmented Lagrangian: f_dim=140, v_dim=110, time_s=4.563, iters=0, constraint_l2=1.139e-04, cost=0.238587
# [cable_robot] constraint manifold basis variables (feasible):
# [cable_robot] [BENCH] \textbf{Constraint Manifold (F)}: f_dim=86, v_dim=60, time_s=0.242, iters=0, constraint_l2=1.280e-12, cost=0.233529
# [cable_robot] constraint manifold basis variables (infeasible):
# [cable_robot] [BENCH] \textbf{Constraint Manifold (I)}: f_dim=86, v_dim=60, time_s=0.167, iters=0, constraint_l2=2.193e-05, cost=0.233527
# [cable_robot] & Soft Constraint & $140 \times 110$ & 1.213 & 205 & 6.05e-03 & 0.34\\
# [cable_robot] & Penalty Method & $140 \times 110$ & 5.968 & 0 & 4.19e-05 & 0.24\\
# [cable_robot] & Augmented Lagrangian & $140 \times 110$ & 4.563 & 0 & 1.14e-04 & 0.24\\
# [cable_robot] & \textbf{Constraint Manifold (F)} & $86 \times 60$ & 0.242 & 0 & 1.28e-12 & 0.23\\
# [cable_robot] & \textbf{Constraint Manifold (I)} & $86 \times 60$ & 0.167 & 0 & 2.19e-05 & 0.23\\
#   -> return_code=0, elapsed=20.12s, log=/Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/cable_robot.log
#
# | benchmark       | benchmark_id    | target                                                                                                                          |   return_code |   elapsed_s | timestamp_utc        | log_path                                                                               |
# |-----------------|-----------------|---------------------------------------------------------------------------------------------------------------------------------|---------------|-------------|----------------------|----------------------------------------------------------------------------------------|
# | arm             | arm             | example_constraint_manifold_arm -> examples/example_constraint_manifold/example_constraint_manifold_arm                         |             0 |      81.820 | 2026-02-08T05:51:24Z | /Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/arm.log             |
# | arm_cm_f_only   | arm             | example_constraint_manifold_arm -> examples/example_constraint_manifold/example_constraint_manifold_arm                         |             0 |       1.473 | 2026-02-08T05:51:25Z | /Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/arm_cm_f_only.log   |
# | connected_poses | connected_poses | example_constraint_manifold_connected_poses -> examples/example_constraint_manifold/example_constraint_manifold_connected_poses |             0 |      13.695 | 2026-02-08T05:51:39Z | /Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/connected_poses.log |
# | cable_robot     | cable_robot     | example_constraint_manifold_cable_robot -> examples/example_constraint_manifold/example_constraint_manifold_cable_robot         |             0 |      20.124 | 2026-02-08T05:51:59Z | /Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/cable_robot.log     |
#
# status CSV: /Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/run_status.csv
# results CSV: /Users/dellaert/git/GTDynamics/build/benchmark_logs_cmopt_notebook/benchmark_results.csv

# %%
rows = read_results_csv(CSV_PATH)

if not rows:
    print('No benchmark rows found in CSV.')
else:
    rows_sorted = sorted(rows, key=lambda r: (r['benchmark'], r['method']))
    print(tabulate(
        rows_sorted,
        headers='keys',
        tablefmt='github',
        floatfmt='.6g',
    ))

    present = {}
    for r in rows_sorted:
        present.setdefault(r['benchmark'], set()).add(r['method'])

    expected_by_benchmark = {}
    for benchmark, target_cfg in TARGETS.items():
        benchmark_id = target_cfg.get('benchmark_id', benchmark)
        expected = set(target_cfg.get('expected_methods', DEFAULT_EXPECTED_METHODS))
        expected_by_benchmark.setdefault(benchmark_id, set()).update(expected)

    summary = []
    for benchmark_id in sorted(expected_by_benchmark.keys()):
        expected_methods = sorted(expected_by_benchmark[benchmark_id])
        got = present.get(benchmark_id, set())
        missing = [m for m in expected_methods if m not in got]
        summary.append({
            'benchmark': benchmark_id,
            'methods_found': ', '.join(sorted(got)) if got else '(none)',
            'missing_expected_methods': ', '.join(missing) if missing else '(none)',
        })

    print('\nMethod coverage summary:')
    print(tabulate(summary, headers='keys', tablefmt='github'))
# Out:
# | benchmark       | method_raw                       | method                  |   f_dim |   v_dim |   time_s |   iters |   constraint_l2 |        cost |
# |-----------------|----------------------------------|-------------------------|---------|---------|----------|---------|-----------------|-------------|
# | arm             | Augmented Lagrangian             | Augmented Lagrangian    |     688 |     605 | 17.477   |       0 |     0.00010625  |    0.233363 |
# | arm             | \textbf{Constraint Manifold (F)} | Constraint Manifold (F) |     146 |      70 |  0.072   |       0 |     0.00318196  |  594.715    |
# | arm             | \textbf{Constraint Manifold (I)} | Constraint Manifold (I) |     146 |      70 |  0.071   |       0 |     0.00318196  |  594.715    |
# | arm             | Penalty Method                   | Penalty Method          |     688 |     605 | 23.6674  |       0 |     2.66998e-05 |    0.234963 |
# | arm             | Soft Constraint                  | Soft Constraint         |     688 |     605 |  3.42    |     205 |     0.00857051  |    0.430867 |
# | cable_robot     | Augmented Lagrangian             | Augmented Lagrangian    |     140 |     110 |  4.563   |       0 |     0.000113894 |    0.238587 |
# | cable_robot     | \textbf{Constraint Manifold (F)} | Constraint Manifold (F) |      86 |      60 |  0.242   |       0 |     1.28037e-12 |    0.233529 |
# | cable_robot     | \textbf{Constraint Manifold (I)} | Constraint Manifold (I) |      86 |      60 |  0.167   |       0 |     2.1932e-05  |    0.233527 |
# | cable_robot     | Penalty Method                   | Penalty Method          |     140 |     110 |  5.9679  |       0 |     4.18843e-05 |    0.239275 |
# | cable_robot     | Soft Constraint                  | Soft Constraint         |     140 |     110 |  1.213   |     205 |     0.00605245  |    0.344925 |
# | connected_poses | Augmented Lagrangian             | Augmented Lagrangian    |     909 |     606 |  2.193   |       0 |    74.9307      |    5.45672  |
# | connected_poses | \textbf{Constraint Manifold (F)} | Constraint Manifold (F) |     606 |     303 |  1.578   |       0 |    63.8406      | 9959.82     |
# | connected_poses | \textbf{Constraint Manifold (I)} | Constraint Manifold (I) |     606 |     303 |  1.324   |       0 |    72.5514      | 5297.17     |
# | connected_poses | Penalty Method                   | Penalty Method          |     909 |     606 |  3.09567 |       0 |    74.9315      |    5.27731  |
# | connected_poses | Soft Constraint                  | Soft Constraint         |     909 |     606 |  0.627   |      28 |    75.2456      |   13.5086   |
#
# Method coverage summary:
# | benchmark       | methods_found                                                                                           | missing_expected_methods   |
# |-----------------|---------------------------------------------------------------------------------------------------------|----------------------------|
# | arm             | Augmented Lagrangian, Constraint Manifold (F), Constraint Manifold (I), Penalty Method, Soft Constraint | (none)                     |
# | cable_robot     | Augmented Lagrangian, Constraint Manifold (F), Constraint Manifold (I), Penalty Method, Soft Constraint | (none)                     |
# | connected_poses | Augmented Lagrangian, Constraint Manifold (F), Constraint Manifold (I), Penalty Method, Soft Constraint | (none)                     |

# %%
def make_grouped_bar(rows, metric: str, title: str, y_title: str, log_y: bool = False):
    methods_order = [
        'Soft Constraint',
        'Penalty Method',
        'Augmented Lagrangian',
        'Constraint Manifold (F)',
        'Constraint Manifold (I)',
    ]
    benchmarks = []
    seen_benchmarks = set()
    for target_name, target_cfg in TARGETS.items():
        benchmark_name = target_cfg.get('benchmark_id', target_name)
        if benchmark_name not in seen_benchmarks:
            seen_benchmarks.add(benchmark_name)
            benchmarks.append(benchmark_name)
    for row in rows:
        benchmark_name = row['benchmark']
        if benchmark_name not in seen_benchmarks:
            seen_benchmarks.add(benchmark_name)
            benchmarks.append(benchmark_name)

    value_map = {}
    for r in rows:
        value_map[(r['benchmark'], r['method'])] = r[metric]

    fig = go.Figure()
    for method in methods_order:
        y = []
        for b in benchmarks:
            y.append(value_map.get((b, method), None))
        if any(v is not None for v in y):
            fig.add_trace(go.Bar(name=method, x=benchmarks, y=y))

    fig.update_layout(
        title=title,
        barmode='group',
        xaxis_title='Benchmark',
        yaxis_title=y_title,
        template='plotly_white',
    )
    if log_y:
        fig.update_yaxes(type='log')
    return fig


if not rows:
    print('No rows to plot.')
else:
    fig_time = make_grouped_bar(rows, 'time_s', 'Runtime Comparison', 'time (s)', log_y=True)
    fig_cost = make_grouped_bar(rows, 'cost', 'Cost Comparison', 'cost', log_y=True)
    fig_constraint = make_grouped_bar(rows, 'constraint_l2', 'Constraint Violation Comparison', 'constraint L2', log_y=True)

    fig_time.show()
    fig_cost.show()
    fig_constraint.show()

# %%
def tail_log(benchmark: str, n: int = 80):
    p = LOG_DIR / f'{benchmark}.log'
    if not p.exists():
        print(f'No log found: {p}')
        return
    lines = p.read_text(errors='replace').splitlines()
    print(f'--- tail({n}) {p} ---')
    for line in lines[-n:]:
        print(line)

# Example:
# tail_log('arm', n=120)
